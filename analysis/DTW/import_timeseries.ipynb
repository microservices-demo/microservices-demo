# %%
import pandas

# %%
test = pandas.read_csv("/home/magnus/Documents/Master/microservices-demo/query/carts-1_cpu=1_time=2h.csv")

# def identify(caller):
#     print(caller)
#     return False
# test.loc(test["identifier"].str.contains("a"))

test["identifier"].str.contains("go_gc")
test.loc[lambda test: test["identifier"].str.contains("go_gc")]
# Out:
#                                            identifier  1671119939  1671120539  \
# 0     go_gc_duration_seconds&catalogue:80&catalogue&0    0.000275    0.000275
# 1   go_gc_duration_seconds&catalogue:80&catalogue&...    0.000309    0.000308
# 2   go_gc_duration_seconds&catalogue:80&catalogue&0.5    0.000324    0.000325
# 3   go_gc_duration_seconds&catalogue:80&catalogue&...    0.000341    0.000339
# 4     go_gc_duration_seconds&catalogue:80&catalogue&1    0.000518    0.000518
# 5         go_gc_duration_seconds&payment:80&payment&0    0.000288    0.000288
# 6      go_gc_duration_seconds&payment:80&payment&0.25    0.000312    0.000312
# 7       go_gc_duration_seconds&payment:80&payment&0.5    0.000326    0.000326
# 8      go_gc_duration_seconds&payment:80&payment&0.75    0.000338    0.000337
# 9         go_gc_duration_seconds&payment:80&payment&1    0.000506    0.000506
# 10              go_gc_duration_seconds&user:80&user&0    0.000283    0.000283
# ...
