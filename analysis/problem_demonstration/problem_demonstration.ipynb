# %% [markdown]
# __Loading the data into a panel format with a MultiIndexed DataFrame__

# %%
import sktime
import pandas as pd
import numpy as np

def make_datetime_index(timestamps:str) -> pd.DatetimeIndex:
    beginning = timestamps[0]
    end = timestamps[-1]
    beginning, end = pd.to_datetime((beginning,end), unit="s")
    index = pd.date_range(start=beginning, end=end, periods=len(timestamps))
    return index

def readcsv_modified(csv_loc:str):
    csv = pd.read_csv(csv_loc)
    metrics = csv["identifier"].to_list()
    timestamps = csv.columns[1:].to_flat_index()
    timestamps = timestamps.to_numpy().tolist()
    timestamps = make_datetime_index(timestamps)
   # index = pd.MultiIndex.from_product([[num], timestamps], names=['instances','timepoints'])
    vals = csv.drop(labels="identifier",axis=1).to_numpy().transpose()
    s = pd.DataFrame(vals, index=timestamps, columns=metrics)
    return s

def removeNaNs(df:pd.DataFrame) -> pd.DataFrame:
    for col in df.columns:
        if df[col].isna().any():
            df = df.drop(col, axis=1)
    return df

def removeUniqueColumns(first:pd.DataFrame, second:pd.DataFrame) -> tuple:
    common_columns = first.columns.intersection(second.columns)
    reduced_old = first.reindex(columns=common_columns)
    reduced_new = second.reindex(columns=common_columns)
    return reduced_old, reduced_new

def readcsvs(csv_loc_list:list):
    individual_dataframes = []
    for i in range(len(csv_loc_list)):
        individual_dataframes.append(readcsv_modified(csv_loc_list[i]))

    #Here: Go through the loop once again, start trimming. compare everything to element at 0, trim with it so it stays as the leanest version.

    removed_nans = []
    for frame in individual_dataframes:
        removed_nans.append(removeNaNs(frame))

    initial_df = removed_nans[0]
    removed_unique_cols = []
    for frame in removed_nans[1:]:
        reduced_frames = removeUniqueColumns(initial_df, frame)
        initial_df = reduced_frames[0]
        removed_unique_cols.append(reduced_frames[1])
    removed_unique_cols.append(initial_df)

    concated = pd.concat(removed_unique_cols, keys=[f'csv {i}' for i in range(1, len(removed_unique_cols)+1)])

    concated.index = pd.MultiIndex.from_tuples([(idx, date) for idx, date in zip(concated.index.get_level_values(0), concated.index.get_level_values(1))], names=['files','times'])

    return concated

# %% [markdown]
# __Resulting dataframe, with some info about it__

# %%
file_list = ["./catalog.csv",
             "./catalog2.csv",
             "./even_load.csv"]
complete_df = readcsvs(file_list)
print(complete_df.shape)
print(complete_df.values.size)
complete_df
# Out:
# (399, 586)
# 233814
#                            go_gc_duration_seconds&catalogue:80&catalogue&0  \
# files times
# csv 1 2023-01-18 17:11:01                                         0.000316
#       2023-01-18 17:11:06                                         0.000316
#       2023-01-18 17:11:11                                         0.000316
#       2023-01-18 17:11:16                                         0.000316
#       2023-01-18 17:11:21                                         0.000316
# ...                                                                    ...
# csv 3 2023-01-18 17:31:59                                         0.000316
#       2023-01-18 17:32:04                                         0.000316
#       2023-01-18 17:32:09                                         0.000316
#       2023-01-18 17:32:14                                         0.000316
#       2023-01-18 17:32:19                                         0.000316
#
#                            go_gc_duration_seconds&catalogue:80&catalogue&0.25  \
# files times
# csv 1 2023-01-18 17:11:01                                           0.000352
#       2023-01-18 17:11:06                                           0.000352
#       2023-01-18 17:11:11                                           0.000352
#       2023-01-18 17:11:16                                           0.000352
#       2023-01-18 17:11:21                                           0.000352
# ...                                                                      ...
# csv 3 2023-01-18 17:31:59                                           0.000352
#       2023-01-18 17:32:04                                           0.000352
#       2023-01-18 17:32:09                                           0.000352
#       2023-01-18 17:32:14                                           0.000352
#       2023-01-18 17:32:19                                           0.000352
#
# ...                                            ...              ...
# csv 3 2023-01-18 17:31:59                      1.0              1.0
#       2023-01-18 17:32:04                      1.0              1.0
#       2023-01-18 17:32:09                      1.0              1.0
#       2023-01-18 17:32:14                      1.0              1.0
#       2023-01-18 17:32:19                      1.0              1.0
#
#                            uptime&carts:80&cart  uptime&orders:80&orders  \
# files times
# csv 1 2023-01-18 17:11:01            24606819.0               24608476.0
#       2023-01-18 17:11:06            24611818.0               24613476.0
#       2023-01-18 17:11:11            24616819.0               24618477.0
#       2023-01-18 17:11:16            24621818.0               24623477.0
#       2023-01-18 17:11:21            24626819.0               24628477.0
# ...                                         ...                      ...
# csv 3 2023-01-18 17:31:59            25861819.0               25863476.0
#       2023-01-18 17:32:04            25866819.0               25868477.0
#       2023-01-18 17:32:09            25871819.0               25873477.0
#       2023-01-18 17:32:14            25876819.0               25878476.0
#       2023-01-18 17:32:19            25881819.0               25883477.0
#
#                            uptime&shipping:80&shipping
# files times
# csv 1 2023-01-18 17:11:01                   24608582.0
#       2023-01-18 17:11:06                   24613583.0
#       2023-01-18 17:11:11                   24618583.0
#       2023-01-18 17:11:16                   24623583.0
#       2023-01-18 17:11:21                   24628583.0
# ...                                                ...
# csv 3 2023-01-18 17:31:59                   25868583.0
#       2023-01-18 17:32:04                   25873583.0
#       2023-01-18 17:32:09                   25878583.0
#       2023-01-18 17:32:14                   25883583.0
#       2023-01-18 17:32:19                   25888583.0
#
# [399 rows x 586 columns]

# %% [markdown]
# __Rocket fails__

# %%
from sktime.transformations.panel.rocket import Rocket

rocket = Rocket()
rocket.fit(complete_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7300\3325979802.py in <module>
#       2
#       3 rocket = Rocket()
# ----> 4 rocket.fit(complete_df)
#
# f:\anaconda\envs\py39\lib\site-packages\sktime\transformations\base.py in fit(self, X, y)
#     396
#     397         # check and convert X/y
# --> 398         X_inner, y_inner = self._check_X_y(X=X, y=y)
#     399
#     400         # memorize X as self._X, if remember_data tag is set to True
#
# f:\anaconda\envs\py39\lib\site-packages\sktime\transformations\base.py in _check_X_y(self, X, y, return_metadata)
#     940         if not requires_vectorization:
#     941             # converts X
# --> 942             X_inner = convert_to(
#     943                 X,
#     944                 to_type=X_inner_mtype,
#
# f:\anaconda\envs\py39\lib\site-packages\sktime\datatypes\_convert.py in convert_to(obj, to_type, as_scitype, store, store_behaviour)
#     261             to_type = same_scitype_mtypes[0]
#     262
# --> 263     converted_obj = convert(
#     264         obj=obj,
#     265         from_type=from_type,
#
# f:\anaconda\envs\py39\lib\site-packages\sktime\datatypes\_convert.py in convert(obj, from_type, to_type, as_scitype, store, store_behaviour)
#     170         )
#     171
# --> 172     converted_obj = convert_dict[key](obj, store=store)
#     173
#     174     return converted_obj
#
# f:\anaconda\envs\py39\lib\site-packages\sktime\datatypes\_panel\_convert.py in from_multi_index_to_3d_numpy_adp(obj, store)
#     589 def from_multi_index_to_3d_numpy_adp(obj, store=None):
#     590
# --> 591     res = from_multi_index_to_3d_numpy(X=obj)
#     592     if isinstance(store, dict):
#     593         store["columns"] = obj.columns
#
# f:\anaconda\envs\py39\lib\site-packages\sktime\datatypes\_panel\_convert.py in from_multi_index_to_3d_numpy(X)
#     582     n_columns = X.shape[1]
#     583
# --> 584     X_3d = X.values.reshape(n_instances, n_timepoints, n_columns).swapaxes(1, 2)
#     585
#     586     return X_3d
#
# ValueError: cannot reshape array of size 233814 into shape (3,399,586)
